# %%
import pandas as pd
import matplotlib.pylab as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import kpss
import scipy.stats as st

# %%
data = pd.read_csv("puchkov.k@phystech.edu.csv", header=None)
data.head(5)
# Out:
#           0
# 0 -0.411853
# 1  1.232414
# 2  1.887065
# 3  2.726599
# 4  2.310457

# %%
plt.figure(figsize = (10,6))
plt.plot(data)
plt.grid()
plt.show()

# %% [markdown]
# ## Найдите период временного ряда

# %%
stl_data = seasonal_decompose(data, period=20)
stl_data.plot()
plt.show()

# %%
plt.plot(data.diff(20))
plt.show()

# %%
plt.plot(data.diff(19))
plt.show()

# %% [markdown]
# **Можно утверждать, что период ряда близок к 20 (просто методом тыка). Андрей Грабовой сказал, что период не больше 19-ти (без понятия, почему так).**

# %% [markdown]
# ## Значение статистики $KPSS$ для остатков в разложение $seaconal\_decompose$, где период указан с предыдущего пункта.

# %%
T = 20
stl_data = seasonal_decompose(data, period=T)
r = stl_data.resid.dropna()
print("Statistic score:", round(kpss(r, nlags='legacy')[0], 3))
# Out:
# Statistic score: 0.074
# /home/hp/.local/lib/python3.8/site-packages/statsmodels/tsa/stattools.py:1910: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(

# %%
T = 21
stl_data = seasonal_decompose(data, period=T)
r = stl_data.resid.dropna()
print("Statistic score:", round(kpss(r, nlags='legacy')[0], 3))
# Out:
# Statistic score: 0.095
# /home/hp/.local/lib/python3.8/site-packages/statsmodels/tsa/stattools.py:1910: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(
